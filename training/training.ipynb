# %% [markdown]
# # Training of Corner Detection Model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/nic_project
# Out:
# /content/drive/MyDrive/nic_project

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 715.1/715.1 kB 16.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt') #load a pretrained model

results = model.train(data = '/content/drive/MyDrive/nic_project/datasets/corner_det/database.yaml', epochs = 500, imgsz = 640, patience = 300)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 93.9MB/s]
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Test the model performance

# %%
from ultralytics import YOLO
from ultralytics.models.yolo.detect import DetectionPredictor
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import cv2
import os
from google.colab import drive

drive.mount('/content/drive')

names_index = ['top left', 'top right', 'bottom right', 'bottom left']
imgWidth = 640
imgHeight = 480

sources_model = '/content/drive/MyDrive/nic_project/models/cornerdetect.pt'
model = YOLO(sources_model)

input_folder = '/content/drive/MyDrive/nic_project/test_images'  # Change this to your input folder
output_folder = '/content/drive/MyDrive/nic_project/model_outputs/cornerdetect'  # Change this to your output folder

# Make sure the output folder exists, create it if necessary
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

def get_index_one_point(coordinates):
    return [int((coordinates[0][0] + coordinates[0][2]) // 2), int((coordinates[0][1] + coordinates[0][3]) // 2)]

def changesize(img):
    h, w = img.shape[0], img.shape[1]
    ratio = w / h
    newW = 640
    newH = int(newW / ratio)
    img1 = cv2.resize(img, (newW, newH))
    return img1

def get_transform(path_image):
    img = cv2.imread(path_image)
    img = changesize(img)
    results = model.predict(source=img)

    dic = {'top left': [],
           'top right': [],
           'bottom right': [],
           'bottom left': []}

    # Track if each corner is successfully detected
    corners_detected = {'top left': False, 'top right': False, 'bottom right': False, 'bottom left': False}

    for box in results[0].boxes:
        name = names_index[int(box.cls[0])]

        # Check if the corner is already detected, if not, add it to the dictionary
        if not corners_detected[name]:
            dic[name] = get_index_one_point(box.xyxy)
            corners_detected[name] = True

    # Check if at least three corners are detected
    if sum(corners_detected.values()) < 4:
        print(f"Failed to detect corners properly in {path_image}. Skipping...")
        return None  # Return None to indicate failure

    # Adjustments for robustness (e.g., selecting only one detection if multiple)
    dic['top left'] = dic['top left'][0] - 10, dic['top left'][1] - 10
    dic['top right'] = dic['top right'][0] + 10, dic['top right'][1] - 10
    dic['bottom right'] = dic['bottom right'][0] - 10, dic['bottom right'][1] + 10
    dic['bottom left'] = dic['bottom left'][0] + 10, dic['bottom left'][1] + 10

    sources_point = np.float32([dic['top left'], dic['top right'], dic['bottom right'], dic['bottom left']])
    dest_points = np.float32([[0, 0], [imgWidth, 0], [imgWidth, imgHeight], [0, imgHeight]])
    matrix = cv2.getPerspectiveTransform(sources_point, dest_points)
    crop_img = cv2.warpPerspective(img, matrix, (imgWidth, imgHeight))

    return crop_img

# Process each image in the input folder and save the cropped images to the output folder
for filename in os.listdir(input_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        crop_img = get_transform(input_path)

        if crop_img is not None:
            cv2.imwrite(output_path, crop_img)
            print(f"Cropped image saved to {output_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# 0: 640x448 1 top_left, 1 top_right, 1 bottom_right, 1 bottom_left, 307.5ms
# Speed: 12.6ms preprocess, 307.5ms inference, 35.3ms postprocess per image at shape (1, 3, 640, 448)
# Cropped image saved to /content/drive/MyDrive/nic_project/model_outputs/cornerdetect/0222.jpg
#
# 0: 640x384 1 top_left, 1 top_right, 2 bottom_rights, 1 bottom_left, 176.1ms
# Speed: 4.7ms preprocess, 176.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Cropped image saved to /content/drive/MyDrive/nic_project/model_outputs/cornerdetect/0245.jpg
#
# 0: 640x384 1 top_left, 1 top_right, 2 bottom_rights, 1 bottom_left, 152.2ms
# Speed: 4.5ms preprocess, 152.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
# Cropped image saved to /content/drive/MyDrive/nic_project/model_outputs/cornerdetect/0257.jpg
#
# ...

# %% [markdown]
# # Training of ID_Number,Gender,BOD Detection Model

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt') #load a pretrained model

results = model.train(data = '/content/drive/MyDrive/nic_project/datasets/id_gen_bod_det/database.yaml', epochs = 500, imgsz = 640, patience = 200)
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Test the model performance

# %%
from ultralytics import YOLO
from ultralytics.models.yolo.detect import DetectionPredictor
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw
import os


imgWidth = 640
imgHeight = 480
# YOLO
sources_model = '/content/drive/MyDrive/nic_project/models/id_gen_bod_detect.pt'
model = YOLO(sources_model)

input_folder = '/content/drive/MyDrive/nic_project/model_outputs/cornerdetect'  # Change this to your input folder
output_folder = '/content/drive/MyDrive/nic_project/model_outputs/id_gen_bod_detect'  # Change this to your output folder

# Process each image in the input folder and save the images with detection boxes to the output folder
for filename in os.listdir(input_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        img = Image.open(input_path)
        img_np = np.array(img)

        results = model.predict(source=img_np)

        draw = ImageDraw.Draw(img)

        for box in results[0].boxes:
            xyxy = [int(coord.item()) for coord in box.xyxy[0]]
            draw.rectangle(xyxy, outline="red", width=2)

        img.save(output_path)

        print(f"Image with detection boxes saved to {output_path}")
# Out:
# 0: 480x640 1 id_number, 1 gender, 1 bod, 15.4ms
# Speed: 2.9ms preprocess, 15.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Image with detection boxes saved to /content/drive/MyDrive/nic_project/model_outputs/id_gen_bod_detect/0259.jpg
#
# 0: 480x640 1 id_number, 1 gender, 1 bod, 13.9ms
# Speed: 1.6ms preprocess, 13.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Image with detection boxes saved to /content/drive/MyDrive/nic_project/model_outputs/id_gen_bod_detect/0246.jpg
#
# 0: 480x640 1 id_number, 1 gender, 1 bod, 10.3ms
# Speed: 2.3ms preprocess, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
# Image with detection boxes saved to /content/drive/MyDrive/nic_project/model_outputs/id_gen_bod_detect/0231.jpg
#
# 0: 480x640 1 id_number, 1 gender, 1 bod, 10.6ms
# Speed: 1.8ms preprocess, 10.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ...

# %% [markdown]
# # Training of Name Detection Model

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt') #load a pretrained model

results = model.train(data = '/content/drive/MyDrive/nic_project/datasets/name_det/database.yaml', epochs = 800, imgsz = 640, patience = 400)
# Out:
# Ultralytics YOLOv8.1.15 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Test the model performance

# %%
from ultralytics import YOLO
from ultralytics.models.yolo.detect import DetectionPredictor
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageDraw


imgWidth = 640
imgHeight = 480
# YOLO
sources_model = '/content/drive/MyDrive/nic_project/models/namedetect.pt'
model = YOLO(sources_model)

input_folder = '/content/drive/MyDrive/nic_project/model_outputs/cornerdetect'  # Change this to your input folder
output_folder = '/content/drive/MyDrive/nic_project/model_outputs/namedetect'  # Change this to your output folder

# Process each image in the input folder and save the images with detection boxes to the output folder
for filename in os.listdir(input_folder):
    if filename.endswith(".jpg") or filename.endswith(".png"):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        img = Image.open(input_path)
        img_np = np.array(img)

        results = model.predict(source=img_np)

        draw = ImageDraw.Draw(img)

        for box in results[0].boxes:
            xyxy = [int(coord.item()) for coord in box.xyxy[0]]
            draw.rectangle(xyxy, outline="red", width=2)

        img.save(output_path)

        print(f"Image with detection boxes saved to {output_path}")
# Out:
# 0: 480x640 3 name1s, 1 name2, 19.9ms
# Speed: 1.7ms preprocess, 19.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# Image with detection boxes saved to /content/drive/MyDrive/nic_project/model_outputs/namedetect/0259.jpg
#
# 0: 480x640 3 name1s, 2 name2s, 10.2ms
# Speed: 2.4ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Image with detection boxes saved to /content/drive/MyDrive/nic_project/model_outputs/namedetect/0246.jpg
#
# 0: 480x640 3 name1s, 9.2ms
# Speed: 2.7ms preprocess, 9.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# Image with detection boxes saved to /content/drive/MyDrive/nic_project/model_outputs/namedetect/0231.jpg
#
# 0: 480x640 2 name1s, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Image with detection boxes saved to /content/drive/MyDrive/nic_project/model_outputs/namedetect/0236.jpg
#
# ...
